# %%
from dataclasses import dataclass, field
import networkx as nx
import matplotlib.pyplot as plt
from simulator import SIRD, SIRDGraph

# %%
nodes: list = [
    ("USA", SIRD(b=1/2, k=1/3, w=1/4, N=1500000, i=0.2), (0.5, 0.5)),
    ("Canada", SIRD(b=1/2, k=1/3, w=1/4, N=1000000, i=0.5), (0.45, 0.4)),
    ("Mexico", SIRD(b=1/2, k=1/3, w=1/4, N=2000000, i=0.99), (0.6, 0.6)),
]

edges: list = [
    ("USA", "Canada", 0.1),
    ("USA", "Mexico", 0.1)
]
# Out:
# Records init.
# Records init.
# Records init.
# Records init.
# Records init.
# Records init.

# %%
sirdg = SIRDGraph(nodes, edges)

# %%
sirdg.run(maxsteps=20)

# %%
sirdg.save_dict()
