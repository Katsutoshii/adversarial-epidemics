# %%
from tools import get_SIRDN_graph, plot_world_map, calculate
from simulator import SIRDGraph

# %%
n, e, G, pos = get_SIRDN_graph(b=1/50000000, insulation=3/128, recovery = 0.08)
# Out:
# spread rate
# ...

# %%
def draw_background():
    plot_world_map(36, 32)

sirdg: SIRDGraph = SIRDGraph(n, e,
    width_factor=3,
    size_factor=1/300,
    font_size=20,
    color_factor=100000,
    y_offset=0.01,
    font_color="blue",
    draw_background=draw_background)

# %%
sirdg.run(1, draw=False)

# %%
sirdg.run(115, draw=False)

# %%
# sirdg.show()

# %%
sirdg.save_dict(filename="../data/out/test.json")

# %%
calculate(k=3)
# Out:
# Missing countries from generated data:  ['u', 'Total']
# [(1204319.4957264957, 'China'), (2933863.3076923075, 'Hong Kong'), (1574686.3333333335, 'India')]
