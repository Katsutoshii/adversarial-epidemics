# %%
import matplotlib.pyplot as plt
import networkx as nx
from simulator import PACGraph

# %%
PG: PACGraph = PACGraph(n=100, m=1000, p_p=1, p_c=0)
# PG.draw()

# %%
PG.G.number_of_edges()
# Out:
# 1000

# %%
nx.transitivity(PG.G)
# Out:
# 0.29156322946385566

# %%
plt.hist([d for n, d in PG.G.degree()], bins=50)
# Out:
# (array([ 7.,  6.,  6.,  5.,  6.,  9., 10.,  6.,  4.,  4.,  2.,  2.,  2.,
#          0.,  1.,  3.,  3.,  2.,  0.,  1.,  2.,  0.,  1.,  2.,  0.,  1.,
#          0.,  2.,  0.,  0.,  2.,  0.,  2.,  1.,  1.,  1.,  1.,  0.,  0.,
#          0.,  0.,  2.,  0.,  0.,  1.,  0.,  0.,  0.,  1.,  1.]),
#  array([ 7.  ,  8.06,  9.12, 10.18, 11.24, 12.3 , 13.36, 14.42, 15.48,
#         16.54, 17.6 , 18.66, 19.72, 20.78, 21.84, 22.9 , 23.96, 25.02,
#         26.08, 27.14, 28.2 , 29.26, 30.32, 31.38, 32.44, 33.5 , 34.56,
#         35.62, 36.68, 37.74, 38.8 , 39.86, 40.92, 41.98, 43.04, 44.1 ,
#         45.16, 46.22, 47.28, 48.34, 49.4 , 50.46, 51.52, 52.58, 53.64,
#         54.7 , 55.76, 56.82, 57.88, 58.94, 60.  ]),
#  <a list of 50 Patch objects>)
