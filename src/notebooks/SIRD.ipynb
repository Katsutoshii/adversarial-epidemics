# %%
import matplotlib.pyplot as plt 
from simulator import SIRD

# %%
sird: SIRD = SIRD()
for i in range(100):
    sird.step()

sird.plot()
# Out:
# Records init.
# Records init.

# %%
sird.get_dict()
# Out:
# {'I': [120.00000000000001,
#   141.3,
#   162.756405,
#   182.85019642492549,
#   199.86767129084114,
#   212.20007406907425,
#   218.68346088960544,
#   218.8554502284797,
#   213.02624601946536,
#   202.1454447514353,
#   187.53737176921308,
#   170.6160051525637,
#   152.66536001481478,
#   134.71764310012125,
#   117.51800150482575,
#   101.54593403645468,
#   87.06392173178189,
#   74.1725741490901,
#   62.86089052578013,
#   53.047006476834994,
#   44.60874836158288,
#   37.40519022220532,
#   31.29103523914683,
#   26.12563733597074,
#   21.778209863379043,
#   18.13043291940226,
#   15.077358192389138,
#   12.52725233582175,
#   10.400821281328994,
#   8.630111611814081,
#   7.1572808099417315,
#   5.933355750779115,
#   4.9170496685501455,
#   4.07367528742769,
#   3.374170835686938,
#   2.794242604572813,
#   2.313619968139332,
#   1.9154145326135945,
#   1.5855730851978385,
#   1.3124134167733255,
#   1.086232336128437,
#   0.8989759046155864,
#   0.7439628614050406,
# ...
